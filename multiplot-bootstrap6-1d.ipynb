# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %%
fileset = 7
nfiles = 0

if fileset == 1 :
    input_filebase1 = 'hist-pdf-toy-study-1d-1a-perfect/correlations'
    input_filebase2 = 'hist-pdf-toy-study-1d-1a-goodres/correlations'
    input_filebase3 = 'hist-pdf-toy-study-1d-1a-nominal-resolution/correlations'
    input_filebase4 = 'hist-pdf-toy-study-1d-1a-badres/correlations'
    nfiles = 4
    legend_labels = ['Perfect resolution',
                    'Good resolution',
                    'Nominal resolution',
                    'Bad resolution']

    
if fileset == 2 :
    input_filebase1 = 'bootstrap-toy-study8a-1d-1d-perfect/correlations'
    input_filebase2 = 'bootstrap-toy-study8a-1d-1d/correlations'
    input_filebase3 = 'bootstrap-toy-study8a-1d-1d-nominal-resolution/correlations'
    input_filebase4 = 'bootstrap-toy-study8a-1d-1d-gpu0/correlations'
    nfiles = 4
    legend_labels = ['Perfect resolution',
                    'Good resolution',
                    'Nominal resolution',
                    'Bad resolution']
    

if fileset == 3 :
    input_filebase1 = 'bootstrap-toy-study8a-1d-1d-nominal-resolution/correlations-xrange-0.00-to-0.50'
    input_filebase2 = 'bootstrap-toy-study8a-1d-1d-nominal-resolution/correlations-xrange-0.50-to-1.50'
    input_filebase3 = 'bootstrap-toy-study8a-1d-1d-nominal-resolution/correlations-xrange-1.50-to-5.00'
    nfiles = 3
    legend_labels = ['feature range [0.0, 0.5]',
                    'feature range [0.5, 1.5]',
                    'feature range [1.5, 5.0]',]
    
if fileset == 4 :
    input_filebase1 = 'hist-pdf-toy-study-1d-1a-nominal-resolution/correlations-xrange-0.00-to-0.50'
    input_filebase2 = 'hist-pdf-toy-study-1d-1a-nominal-resolution/correlations-xrange-0.50-to-1.50'
    input_filebase3 = 'hist-pdf-toy-study-1d-1a-nominal-resolution/correlations-xrange-1.50-to-5.00'
    nfiles = 3
    legend_labels = ['feature range [0.0, 0.5]',
                    'feature range [0.5, 1.5]',
                    'feature range [1.5, 5.0]',]    
    
if fileset == 5 :
    input_filebase1 = 'bootstrap-toy-study8a-1d-1d/correlations-xrange-0.00-to-0.50'
    input_filebase2 = 'bootstrap-toy-study8a-1d-1d/correlations-xrange-0.50-to-1.50'
    input_filebase3 = 'bootstrap-toy-study8a-1d-1d/correlations-xrange-1.50-to-5.00'
    nfiles = 3
    legend_labels = ['feature range [0.0, 0.5]',
                    'feature range [0.5, 1.5]',
                    'feature range [1.5, 5.0]',]
    
    
if fileset == 6 :
    input_filebase1 = 'bootstrap-toy-study8a-1d-1d-perfect/correlations-xrange-0.00-to-0.50'
    input_filebase2 = 'bootstrap-toy-study8a-1d-1d-perfect/correlations-xrange-0.50-to-1.50'
    input_filebase3 = 'bootstrap-toy-study8a-1d-1d-perfect/correlations-xrange-1.50-to-5.00'
    nfiles = 3
    legend_labels = ['feature range [0.0, 0.5]',
                    'feature range [0.5, 1.5]',
                    'feature range [1.5, 5.0]',]
        

        
if fileset == 7 :
    input_filebase1 = 'hist-pdf-toy-study-1d-1a-perfect/correlations-xrange-0.00-to-0.50'
    input_filebase2 = 'hist-pdf-toy-study-1d-1a-perfect/correlations-xrange-0.50-to-1.50'
    input_filebase3 = 'hist-pdf-toy-study-1d-1a-perfect/correlations-xrange-1.50-to-5.00'
    nfiles = 3
    legend_labels = ['feature range [0.0, 0.5]',
                    'feature range [0.5, 1.5]',
                    'feature range [1.5, 5.0]',]

# %%
with open( '%s.npy' % input_filebase1, 'rb') as f :
    all1_points_df0 = np.load(f)
    all1_points_corr_array = np.load(f)

# %%
with open( '%s.npy' % input_filebase2, 'rb') as f :
    all2_points_df0 = np.load(f)
    all2_points_corr_array = np.load(f)

# %%
with open( '%s.npy' % input_filebase3, 'rb') as f :
    all3_points_df0 = np.load(f)
    all3_points_corr_array = np.load(f)

# %%
if nfiles > 3 :
    with open( '%s.npy' % input_filebase4, 'rb') as f :
        all4_points_df0 = np.load(f)
        all4_points_corr_array = np.load(f)

# %%
all1_points_df0 = np.absolute(all1_points_df0)
all2_points_df0 = np.absolute(all2_points_df0)
all3_points_df0 = np.absolute(all3_points_df0)

if nfiles > 3 :
    all4_points_df0 = np.absolute(all4_points_df0)

# %%
plt.hist2d(all1_points_df0,all1_points_corr_array,bins=[80,80])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist2d(all2_points_df0,all2_points_corr_array,bins=[80,80])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist2d(all3_points_df0,all3_points_corr_array,bins=[80,80])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
if nfiles > 4 :

    plt.hist2d(all4_points_df0,all4_points_corr_array,bins=[80,80])
    plt.show

# %%
def profile2d_from_hdata( axis, hist_data,  drawline=True, hlabel="" ) :
    
        
    nybins = len(hist_data[0][0])
    print("number of y bins: %d" % nybins)

    nxbins = len(hist_data[0])
    print("number of x bins: %d" % nxbins)



    x_vals = np.zeros( nxbins )
    avey_vals = np.zeros( nxbins )
    rmsy_vals = np.zeros( nxbins )

    for xbi in range( nxbins ) :

        wsum = 0
        ywsum = 0
        yywsum = 0

        xval = 0.5 * ( hist_data[1][xbi] + hist_data[1][xbi+1] )
        #print(" xbin %d has center at %6.3f" % ( xbin_ind, xval ))

        for ybi in range( nybins-1 ) :  # don't include the y-bin that corresponds to rho=1 (event with itself)
            yval = 0.5 * ( hist_data[2][ybi] + hist_data[2][ybi+1] )
            bin_content = hist_data[0][xbi][ybi]
            wsum = wsum + bin_content
            ywsum = ywsum + yval * bin_content
            yywsum = yywsum + yval * yval * bin_content
            #print("  %3d : y = %6.3f  bin content = %7d" % (bi, yval, bin_content))

        ave_y = ywsum / wsum
        ave_yy = yywsum / wsum
        rms_y = ave_yy - ave_y * ave_y
        #print(" Ave y = %.3f, RMS y = %.3f" % ( ave_y, rms_y) )

        x_vals[xbi] = xval
        avey_vals[xbi] = ave_y
        rmsy_vals[xbi] = rms_y


    #for xbi in range( nxbins ) :
        #print("  %4d :  x = %7.3f   ave y = %7.3f  rms y = %7.3f" % ( xbi, x_vals[xbi], avey_vals[xbi], rmsy_vals[xbi]))

    if drawline :
        axis.plot( (hist_data[1][0], hist_data[1][-1]), (0,0) )  
    
    axis.errorbar( x_vals, avey_vals, yerr=rmsy_vals, fmt='-o', label=hlabel)
    

    
    plt.show

# %%
def profile2d( axis, xvals, yvals, hbins, hrange, drawhist=True, drawline=True, hlabel="" ) :
    
    hist_data = axis.hist2d( xvals, yvals, bins=hbins, range=hrange)
    
    if not drawhist :
        axis.cla()
        axis.plot((0),(0))
        axis.set_xlim(hrange[0])
        axis.set_ylim(hrange[1])
    
    profile2d_from_hdata( axis, hist_data, drawline, hlabel )

# %%
fig,ax = plt.subplots(1,nfiles,figsize=(20,6))


profile2d( ax[0], all1_points_df0, all1_points_corr_array, hbins=[80,80], hrange=([0,5],[-0.99,1]), drawhist=True,
         hlabel=legend_labels[0])
profile2d( ax[1], all2_points_df0, all2_points_corr_array, hbins=[80,80], hrange=([0,5],[-0.99,1]), drawhist=True,
         hlabel=legend_labels[1])
profile2d( ax[2], all3_points_df0, all3_points_corr_array, hbins=[80,80], hrange=([0,5],[-0.99,1]), drawhist=True,
         hlabel=legend_labels[2])

if nfiles > 3 :
    profile2d( ax[3], all4_points_df0, all4_points_corr_array, hbins=[80,80], hrange=([0,5],[-0.99,1]), drawhist=True,
         hlabel=legend_labels[3])

ax[0].set_xlabel('Feature distance', fontsize=15)
ax[0].set_ylabel('2-point weight correlation', fontsize=15)

ax[1].set_xlabel('Feature distance', fontsize=15)
ax[1].set_ylabel('2-point weight correlation', fontsize=15)

ax[2].set_xlabel('Feature distance', fontsize=15)
ax[2].set_ylabel('2-point weight correlation', fontsize=15)

ax[0].legend(loc='best', fontsize=17)
ax[1].legend(loc='best', fontsize=17)
ax[2].legend(loc='best', fontsize=17)
if nfiles > 3 :
    ax[3].legend(loc='best', fontsize=17)

plt.subplots_adjust( wspace=0.35 )

plt.show
# Out:
# number of y bins: 80
# number of x bins: 80
# number of y bins: 80
# number of x bins: 80
# number of y bins: 80
# number of x bins: 80
# /tmp/ipykernel_1787559/3051685148.py:33: RuntimeWarning: invalid value encountered in scalar divide
#   ave_y = ywsum / wsum
# /tmp/ipykernel_1787559/3051685148.py:34: RuntimeWarning: invalid value encountered in scalar divide
#   ave_yy = yywsum / wsum
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize=15)

fig,ax = plt.subplots(1,1,figsize=(12,7))

hd1 = ax.hist2d(all1_points_df0, all1_points_corr_array, bins=[80,80], range=([0,5],[-0.9,1]))
hd2 = ax.hist2d(all2_points_df0, all2_points_corr_array, bins=[80,80], range=([0,5],[-0.9,1]))
hd3 = ax.hist2d(all3_points_df0, all3_points_corr_array, bins=[80,80], range=([0,5],[-0.9,1]))
if nfiles > 3 :
    hd4 = ax.hist2d(all4_points_df0, all4_points_corr_array, bins=[80,80], range=([0,5],[-0.9,1]))

ax.cla()
ax.plot((0),(0))
ax.set_xlim([0,5])
ax.set_ylim([-0.9,1.1])



profile2d_from_hdata( ax, hd1, hlabel=legend_labels[0])
profile2d_from_hdata( ax, hd2, drawline=False, hlabel=legend_labels[1])
profile2d_from_hdata( ax, hd3, drawline=False, hlabel=legend_labels[2])
if nfiles > 3 :
    profile2d_from_hdata( ax, hd4, drawline=False, hlabel=legend_labels[3])

ax.legend(loc='best', fontsize=17)

ax.set_xlabel('Feature distance', fontsize=15)
ax.set_ylabel('Average 2-point weight correlation', fontsize=15)
# Out:
# number of y bins: 80
# number of x bins: 80
# number of y bins: 80
# number of x bins: 80
# number of y bins: 80
# number of x bins: 80
# /tmp/ipykernel_1787559/3051685148.py:33: RuntimeWarning: invalid value encountered in scalar divide
#   ave_y = ywsum / wsum
# /tmp/ipykernel_1787559/3051685148.py:34: RuntimeWarning: invalid value encountered in scalar divide
#   ave_yy = yywsum / wsum
# Text(0, 0.5, 'Average 2-point weight correlation')
