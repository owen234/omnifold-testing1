# %%
import matplotlib.pyplot as plt
import numpy as np

import time

import sys
import os

from datetime import datetime
import subprocess

os.environ['CUDA_VISIBLE_DEVICES']="1"


from keras.layers import Dense, Input
from keras.models import Model

import omnifold6b as of

import tensorflow as tf

import simple_pdf1a as simple_pdf

import gc

# %%
print("\n\n")
print("  numpy version:  %s" % str(np.version.version) )
print("  tensorflow version:  %s" % str(tf.__version__))
print("\n\n")
# Out:
#   numpy version:  1.21.5
#   tensorflow version:  2.11.0

# %% [markdown]
# ## Set model and resolution parameters

# %%
ndim = 2

##-------------

train_mu = [ 0.0, 1.0 ]



train_rho = [ [-0.6] ]






train_sig = [ 1.0, 1.5 ]


##-------------


true_mu = [ 0.2, 0.8 ]






true_rho  = [ [-0.6] ]



true_sig = [ 0.9, 1.3 ]



#--- nominal
resolution = [ 0.5, 0.8  ]

#--- poor
#resolution = [ 1.0, 1.6  ]






train_cov = np.zeros( shape=(ndim,ndim) )
true_cov  = np.zeros( shape=(ndim,ndim) )

print("\n\n\n Train covariance:")

for i in range(ndim) :
    for j in range(ndim) :
        if j < i : continue
        if i == j :
            train_cov[i][j] = train_sig[i] * train_sig[j]
            print("  %2d, %2d : diagonal  %8.4f" % (i,j, train_cov[i][j]))
        else :
            k = ndim - j - 1
            train_cov[i][j] = train_sig[i] * train_sig[j] * train_rho[i][k]
            train_cov[j][i] = train_cov[i][j]
            print("  %2d, %2d :           %8.3f * %8.3f * %8.3f = %8.4f" % 
                  (i,j, train_sig[i], train_sig[j], train_rho[i][k], train_cov[i][j]))
            
            

print("\n\n\n True covariance:")  

for i in range(ndim) :
    for j in range(ndim) :
        if j < i : continue
        if i == j :
            true_cov[i][j] = true_sig[i] * true_sig[j]
            print("  %2d, %2d : diagonal  %8.4f" % (i,j, true_cov[i][j]))
        else :
            k = ndim - j - 1
            true_cov[i][j] = true_sig[i] * true_sig[j] * true_rho[i][k]
            true_cov[j][i] = true_cov[i][j]
            print("  %2d, %2d :           %8.3f * %8.3f * %8.3f = %8.4f" % 
                  (i,j, true_sig[i], true_sig[j], true_rho[i][k], true_cov[i][j]))
            
            
                

                
                




#-- about 3 min
ngen_train = 120000
ngen_true =  12000

#-- about 33 min
ngen_train = 360000
ngen_true =  36000

#-- about 0.3 min
#ngen_train = 40000
#ngen_true =  4000

#-- about 2.5 min
ngen_train = 100000
ngen_true =   10000

#-- testing
#ngen_train = 30000
#ngen_true =   3000

#of_niter = 10
of_niter = 5






batch_size_setval = int( ngen_true )



output_dir = 'bootstrap-simple-pdf-toy-study6b-2d-v1b'

save_step2_model = True



##-- new stuff for pdf estimation

radius = np.zeros( ndim )

for i in range(ndim) :
    radius[i] = resolution[i] 
    
norm_radius2 = 0.5
# Out:
#  Train covariance:
#    0,  0 : diagonal    1.0000
#    0,  1 :              1.000 *    1.500 *   -0.600 =  -0.9000
#    1,  1 : diagonal    2.2500
#
#
#
#  True covariance:
#    0,  0 : diagonal    0.8100
#    0,  1 :              0.900 *    1.300 *   -0.600 =  -0.7020
#    1,  1 : diagonal    1.6900

# %%
try:
    os.mkdir( output_dir )
except:
    print('\n\n Output directory already exists:  %s' % output_dir)
    #print('\n\n HALTING EXECUTION\n\n')
    #sys.exit()

# %%
print("\n\n")
print("Train covariance determinant:  %f" % np.linalg.det( train_cov ) )
print("True covariance determinant:   %f" % np.linalg.det( true_cov ) )
print("\n\n")
# Out:
# Train covariance determinant:  1.440000
# True covariance determinant:   0.876096

# %%
train_cov_inv = np.linalg.inv( train_cov )

# %%
train_cov_inv_test = np.matmul( train_cov, train_cov_inv )

# %%
print("\n\n")
print(" Train covariance")
print( train_cov )
print("\n Train covariance inverse")
print( train_cov_inv )
print("\n Train covariance inverse test")
print(train_cov_inv_test)
print("\n\n")
# Out:
#  Train covariance
# [[ 1.   -0.9 ]
#  [-0.9   2.25]]
#
#  Train covariance inverse
# [[1.5625     0.625     ]
#  [0.625      0.69444444]]
#
#  Train covariance inverse test
# [[ 1.00000000e+00 -3.82410153e-17]
#  [-5.55111512e-17  1.00000000e+00]]

# %%
true_cov_inv = np.linalg.inv( true_cov )

# %%
true_cov_inv_test = np.matmul( true_cov, true_cov_inv )

# %%
print("\n\n")
print(" True covariance")
print( true_cov )
print("\n True covariance inverse")
print( true_cov_inv )
print("\n True covariance inverse test")
print(true_cov_inv_test)
print("\n\n")
# Out:
#  True covariance
# [[ 0.81  -0.702]
#  [-0.702  1.69 ]]
#
#  True covariance inverse
# [[1.92901235 0.80128205]
#  [0.80128205 0.92455621]]
#
#  True covariance inverse test
# [[ 1.00000000e+00  3.80221824e-17]
#  [-5.90695584e-17  1.00000000e+00]]

# %% [markdown]
# ## Generate samples, save events and config

# %%
train_pts = np.random.multivariate_normal(train_mu, train_cov, size=ngen_train)
true_pts = np.random.multivariate_normal(true_mu, true_cov, size=ngen_true)

train_det_pts = np.random.normal( train_pts, resolution )

true_det_pts = np.random.normal( true_pts, resolution )

train_both = np.stack([train_pts, train_det_pts], axis=1)

# %%
with open( '%s/train-and-true-samples.npy' % output_dir, 'wb') as f :
    np.save(f, train_pts)
    np.save(f, train_det_pts)
    np.save(f, true_pts)
    np.save(f, true_det_pts)

# %%
with open( '%s/config-pars.npy' % output_dir , 'wb' ) as f :
    np.save( f, train_mu )
    np.save( f, train_rho )
    np.save( f, train_sig )
    np.save( f, true_mu )
    np.save( f, true_rho )
    np.save( f, true_sig )
    np.save( f, resolution )
    np.save( f, train_cov )
    np.save( f, true_cov )

# %%
config_filename = '%s/config.txt' % output_dir

config_file = open( config_filename, 'w' )

config_file.write('%s\n\n' % datetime.now() )
config_file.write('ngen_train %d\n' % ngen_train )
config_file.write('ngen_true  %d\n' % ngen_true )
config_file.write('of_niter   %d\n' % of_niter )
config_file.write('ndim       %d\n' % ndim )
config_file.write('radius : %s\n' % str(radius))
config_file.write('norm_radius2 : %.4f' % norm_radius2 )


config_file.write('\n\n')
config_file.write('train_mu : %s\n' % str(train_mu))
config_file.write('train_rho : %s\n' % str(train_rho))
config_file.write('train_sig : %s\n' % str(train_sig))
config_file.write('train_cov : %s\n' % str(train_cov))
config_file.write('\n\n')
config_file.write('true_mu : %s\n' % str(true_mu))
config_file.write('true_rho : %s\n' % str(true_rho))
config_file.write('true_sig : %s\n' % str(true_sig))
config_file.write('true_cov : %s\n' % str(true_cov))
config_file.write('\n\n')
config_file.write('resolution : %s\n' % str(resolution) )
config_file.close()

print('\n\n  Config file contents : %s\n' % config_filename )
print( subprocess.getoutput('cat %s' % config_filename ))
print('\n\n')
# Out:
#   Config file contents : bootstrap-simple-pdf-toy-study6b-2d-v1b/config.txt
#
# 2024-03-06 11:58:45.689879
#
# ngen_train 100000
# ngen_true  10000
# of_niter   5
# ndim       2
# radius : [0.5 0.8]
# norm_radius2 : 0.5000
#
# train_mu : [0.0, 1.0]
# train_rho : [[-0.6]]
# train_sig : [1.0, 1.5]
# train_cov : [[ 1.   -0.9 ]
#  [-0.9   2.25]]
#
#
# true_mu : [0.2, 0.8]
# true_rho : [[-0.6]]
# true_sig : [0.9, 1.3]
# true_cov : [[ 0.81  -0.702]
#  [-0.702  1.69 ]]
#
#
# resolution : [0.5, 0.8]

# %% [markdown]
# ## Plots to visualize these parameter choices

# %%
fig,ax = plt.subplots( ndim, ndim, figsize=(ndim*5, ndim*5))

hmin=-6
hmax=6
hbins=40

for i in range(ndim) :
    for j in range(ndim) :
        if j < i : continue
        ax[i][j].hist2d( train_pts[:,i], train_pts[:,j], bins=[hbins,hbins], range=([hmin,hmax],[hmin,hmax]))



plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots( ndim, ndim, figsize=(ndim*5, ndim*5))

hmin=-6
hmax=6
hbins=40

for i in range(ndim) :
    for j in range(ndim) :
        if j < i : continue
        ax[i][j].hist2d( true_pts[:,i], true_pts[:,j], bins=[hbins,hbins], range=([hmin,hmax],[hmin,hmax]))



plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots( 1, ndim, figsize=(ndim*5,5))

hmin=-6
hmax=6
hbins=40


for i in range(ndim) :
        k = i*3 + j
        ax[i].hist( train_pts[:,i],bins=hbins, range=[hmin,hmax], density=True )
        ax[i].hist( true_pts[:,i],bins=hbins, range=[hmin,hmax], density=True, alpha=0.5 )
    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Estimate initial pdfs
# Need pdf values for both train (MC) and true (fake data) at the location of each train event to comput the weight.  If that's too slow, could evaluate both in a grid and use the closest grid point for computing the weights.
#
# To do it in the numpy way (without loops) will need N^2 arrays?  Or 2 x N arrays?
#
# Did initial testing on laptop (work/ai/jupyter-notebooks).
#
# To make things efficient, especially beyond one iteration, calculate a N x N array of booleans (for the MC), where it saves for each event pair whether the events are within the radius defining the density estimate.
#
# Since the weights are applied to the MC, will need a Ndata x Nmc array of booleans for the data?
#
# For the data, there are no evolving weights, so what's really needed is just a measure of the probability density at the location of the MC events.  Calculate it once and then use the same numbers in each iteration.

# %%
#global train_train_det_within_sphere
train_train_det_within_sphere = np.zeros( shape=(ngen_train ,ngen_train), dtype=bool )

#global train_train_gen_within_sphere
train_train_gen_within_sphere = np.zeros( shape=(ngen_train ,ngen_train), dtype=bool )

# %%
# %%time

rd = simple_pdf.simple_pdf1a( train_both, true_det_pts, 
                             train_train_det_within_sphere, train_train_gen_within_sphere,
                             of_niter, radius, norm_radius2, True, True )
# Out:
#   ======== simple_pdf1a
#
#
#   shape of theta0_S : (100000, 2)
#   shape of theta0_G : (100000, 2)
#   shape of theta_unknown_S : (10000, 2)
#
#   iterations = 5
#
#   scales : [0.5 0.8]
#   radius = 0.50
#
#   compute radii :  True
#   ndim : 2
#
#
#
#
#
#  Calculating distance between all pairs of MC events
#              0 /       100000
#          10000 /       100000
#          20000 /       100000
#          30000 /       100000
#          40000 /       100000
#          50000 /       100000
#          60000 /       100000
#          70000 /       100000
#          80000 /       100000
#          90000 /       100000
#   --- Done calculating
#  train_train_det_within_sphere
# [[ True False False ... False False False]
#  [False  True False ... False False False]
#  [False False  True ... False False False]
#  ...
#  [False False False ...  True False False]
#  [False False False ... False  True False]
#  [False False False ... False False  True]]
#
#
#  Calculating pdf from data, detector features
# true_det_simple_pdf_at_train_points
# [1.95570341e-05 2.23326654e-07 5.10460924e-07 ... 1.81851704e-05
#  5.58316635e-06 7.84833670e-06]
#
# ITERATION: 1
#
#    -- ITERATION 1  STEP 1
#
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#
#    -- ITERATION 1  STEP 2
#
#
# ITERATION: 2
#
#    -- ITERATION 2  STEP 1
#
#  weights_push at the beginning
# [1.18594037 0.40586068 0.93731496 ... 1.01121698 0.98583186 1.13765359]
#
#    -- ITERATION 2  STEP 2
#
#
# ITERATION: 3
#
#    -- ITERATION 3  STEP 1
#
#  weights_push at the beginning
# [1.23928618 0.31060275 0.8537333  ... 1.02502541 0.96097637 1.15714796]
#
#    -- ITERATION 3  STEP 2
#
#
# ITERATION: 4
#
#    -- ITERATION 4  STEP 1
#
#  weights_push at the beginning
# [1.25720132 0.28484312 0.81464106 ... 1.03501679 0.93414909 1.17090276]
#
#    -- ITERATION 4  STEP 2
#
#
# ITERATION: 5
#
#    -- ITERATION 5  STEP 1
#
#  weights_push at the beginning
# [1.26327635 0.27675513 0.80101506 ... 1.0415265  0.90883598 1.18860278]
#
#    -- ITERATION 5  STEP 2
#
# CPU times: user 3min 23s, sys: 6.88 s, total: 3min 30s
# Wall time: 3min 30s

# %%
of_weights = rd["weights"]

mc_weight_sf = (1.*len(true_det_pts))/(1.*len(train_both))

push_weights = rd["push_weights"]
push_weights_scaled = np.copy( push_weights )
push_weights_scaled = mc_weight_sf * push_weights

final_push_weights = rd["final_push_weights"]
final_push_weights_scaled = np.copy(final_push_weights)
final_push_weights_scaled = mc_weight_sf * final_push_weights

with open( '%s/omnifold-output-weights.npy' % output_dir, 'wb') as f :
    np.save(f, final_push_weights_scaled)

# %%
fig,ax = plt.subplots( of_niter, ndim, figsize=(18,4*of_niter))

hmin=-6
hmax=6
hbins=40

hist_data_mc_ofweighted = np.zeros( shape=(of_niter,ndim,hbins))
hist_data_truth         = np.zeros( shape=(of_niter,ndim,hbins))

lfontsize = 17

plt.subplots_adjust( hspace=0.30)
plt.subplots_adjust( wspace=0.25)

do_renorm = True


for ofi in range(0,of_niter) :

    if do_renorm :
        
        for di in range(ndim) :
            
            ax[ofi][di].hist( train_pts[:,di], bins=hbins, density=True, range=[hmin,hmax], label='train particle' )
            hist_data_mc_ofweighted[ofi,di],_,_ = ax[ofi][di].hist( train_pts[:,di], weights=push_weights[ofi], bins=hbins, density=True, range=[hmin,hmax], label='OF weighted particle', alpha=0.5 )
            hist_data_truth[ofi,di],_,_ =         ax[ofi][di].hist( true_pts[:,di], bins=hbins, density=True, range=[hmin,hmax], label='true particle', histtype='step', color='black' )


    else :
        
        for di in range(ndim) :

        
            hist_data_mc_ofweighted[ofi,di],_,_ = ax[ofi][di].hist( train_pts[:,di], weights=push_weights_scaled[ofi], bins=hbins, range=[hmin,hmax], label='OF weighted particle', alpha=0.5 )
            hist_data_truth[ofi,di],_,_ =         ax[ofi][di].hist( true_pts[:,di], bins=hbins, range=[hmin,hmax], label='true particle', histtype='step', color='black' )

        

    
    #ax[ofi][0].legend(loc='best', fontsize=13)
    #ax[ofi][1].legend(loc='best', fontsize=13)
    
    
    ax[ofi][0].set_xlabel('Feature 0', fontsize=lfontsize )
    
    ax[ofi][1].set_xlabel('Feature 1', fontsize=lfontsize )
    
    ax[ofi][0].set_title('Iteration %d' % ofi, fontsize=lfontsize )



plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
hist_data_diff = hist_data_mc_ofweighted - hist_data_truth
hist_data_diff2 = hist_data_diff * hist_data_diff

hist_data_sum_diff2 = np.zeros( shape=(of_niter,ndim))

for ofi in range( of_niter ) :
    for di in range( ndim ) :
        hist_data_sum_diff2[ofi,di] = np.sum( hist_data_diff2[ofi,di])

# %%
fig,ax = plt.subplots( 1, ndim, figsize=(18,5))

for ofi in range(of_niter) :
    for di in range( ndim ) :
        ax[di].plot(hist_data_diff[ofi,di])

    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots( 1, ndim, figsize=(18,5))

ofi = 0
for di in range( ndim ) :
    ax[di].plot(hist_data_diff[ofi,di])

ofi = of_niter-1
for di in range( ndim ) :
    ax[di].plot(hist_data_diff[ofi,di])

    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots( 1, 2, figsize=(18,5))
ax[0].plot( hist_data_sum_diff2)
ax[1].plot( hist_data_sum_diff2)
ax[1].set_yscale('log')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots( of_niter, 4, figsize=(24,7*of_niter))

hmin=-6
hmax=6
hbins=40

lfontsize = 17

plt.subplots_adjust( hspace=0.30)
plt.subplots_adjust( wspace=0.25)

for ofi in range(0,of_niter) :

    ax[ofi][0].hist( of_weights[ofi,0,:], bins=hbins, range=[0.,1.5] )
    ax[ofi][1].hist( of_weights[ofi,1,:], bins=hbins, range=[0.,1.5] )
    ax[ofi][2].hist( push_weights[ofi,:], bins=hbins, range=[0.,4.] )
    ax[ofi][3].hist2d( of_weights[ofi,0,:], of_weights[ofi,1,:], bins=[hbins,hbins] )
    
    ax[ofi][0].set_xlabel( 'step 1 weight', fontsize=lfontsize )
    
    ax[ofi][1].set_xlabel( 'step 2 weight', fontsize=lfontsize )
    
    ax[ofi][3].set_xlabel( 'step 1 weight', fontsize=lfontsize )
    ax[ofi][3].set_ylabel( 'step 2 weight', fontsize=lfontsize )
    
    ax[ofi][0].set_title('Iteration %d' % ofi, fontsize=lfontsize )
    
    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots( 1, 2, figsize=(8*2,5))

hbins=80

final_push_weights_scaled = np.clip( final_push_weights_scaled, 1e-11, 1e11)

ax[0].hist( final_push_weights_scaled, bins=hbins)
ax[0].set_yscale('log')

ax[1].hist( np.log10(final_push_weights_scaled), bins=hbins)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots( of_niter, ndim, figsize=(18,4*of_niter))

hmin=-6
hmax=6
hbins=40

det_hist_data_mc_ofweighted = np.zeros( shape=(of_niter,ndim,hbins))
det_hist_data_truth         = np.zeros( shape=(of_niter,ndim,hbins))

lfontsize = 17

plt.subplots_adjust( hspace=0.30)
plt.subplots_adjust( wspace=0.25)

do_renorm = True


for ofi in range(0,of_niter) :

    if do_renorm :
        
        for di in range(ndim) :
            
            ax[ofi][di].hist( train_det_pts[:,di], bins=hbins, density=True, range=[hmin,hmax], label='train particle' )
            det_hist_data_mc_ofweighted[ofi,di],_,_ = ax[ofi][di].hist( train_det_pts[:,di], weights=push_weights[ofi], bins=hbins, density=True, range=[hmin,hmax], label='OF weighted particle', alpha=0.5 )
            det_hist_data_truth[ofi,di],_,_ =         ax[ofi][di].hist( true_det_pts[:,di], bins=hbins, density=True, range=[hmin,hmax], label='true particle', histtype='step', color='black' )


    else :
        
        for di in range(ndim) :

        
            det_hist_data_mc_ofweighted[ofi,di],_,_ = ax[ofi][di].hist( train_det_pts[:,di], weights=push_weights_scaled[ofi], bins=hbins, range=[hmin,hmax], label='OF weighted particle', alpha=0.5 )
            det_hist_data_truth[ofi,di],_,_ =         ax[ofi][di].hist( true_det_pts[:,di], bins=hbins, range=[hmin,hmax], label='true particle', histtype='step', color='black' )

        

    
    #ax[ofi][0].legend(loc='best', fontsize=13)
    #ax[ofi][1].legend(loc='best', fontsize=13)
    
    
    ax[ofi][0].set_xlabel('Feature 0', fontsize=lfontsize )
    
    ax[ofi][1].set_xlabel('Feature 1', fontsize=lfontsize )
    
    ax[ofi][0].set_title('Iteration %d' % ofi, fontsize=lfontsize )



plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
det_hist_data_diff = det_hist_data_mc_ofweighted - det_hist_data_truth
det_hist_data_diff2 = det_hist_data_diff * det_hist_data_diff

det_hist_data_sum_diff2 = np.zeros( shape=(of_niter,ndim))

for ofi in range( of_niter ) :
    for di in range( ndim ) :
        det_hist_data_sum_diff2[ofi,di] = np.sum( det_hist_data_diff2[ofi,di])

# %%
fig,ax = plt.subplots( 1, ndim, figsize=(18,5))

for ofi in range(of_niter) :
    for di in range( ndim ) :
        ax[di].plot(det_hist_data_diff[ofi,di])

    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots( 1, ndim, figsize=(18,5))

ofi = 0
for di in range( ndim ) :
    ax[di].plot(det_hist_data_diff[ofi,di])

ofi = of_niter-1
for di in range( ndim ) :
    ax[di].plot(det_hist_data_diff[ofi,di])

    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots( 1, 2, figsize=(18,5))
ax[0].plot( det_hist_data_sum_diff2)
ax[1].plot( det_hist_data_sum_diff2)
ax[1].set_yscale('log')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
step1_mean = np.zeros( of_niter )
step1_rms = np.zeros( of_niter )

step2_mean = np.zeros( of_niter )
step2_rms = np.zeros( of_niter )

iter_val = np.zeros( of_niter )

for ofi in range( of_niter ) :
    
    iter_val[ofi] = ofi
    
    step1_mean[ofi] = np.mean( of_weights[ofi,0,:] )
    step1_rms[ofi] = np.sqrt( np.var( of_weights[ofi,0,:]))
    
    step2_mean[ofi] = np.mean( of_weights[ofi,1,:] )
    step2_rms[ofi] = np.sqrt( np.var( of_weights[ofi,1,:]))
    
    print("  iter %2d : step 1 mean  %.3f  rms %.3f      step 2 mean  %.3f  rms %.3f" % 
          (ofi, step1_mean[ofi], step1_rms[ofi], step2_mean[ofi], step2_rms[ofi]) )
# Out:
#   iter  0 : step 1 mean  0.940  rms 0.234      step 2 mean  0.959  rms 0.182
#   iter  1 : step 1 mean  0.959  rms 0.144      step 2 mean  0.972  rms 0.067
#   iter  2 : step 1 mean  0.975  rms 0.136      step 2 mean  0.985  rms 0.038
#   iter  3 : step 1 mean  0.983  rms 0.134      step 2 mean  0.990  rms 0.029
#   iter  4 : step 1 mean  0.987  rms 0.133      step 2 mean  0.993  rms 0.025

# %%
fig,ax = plt.subplots( 1, 2, figsize=(18,7))

ax[0].plot( iter_val, step1_mean )
ax[0].plot( iter_val, step2_mean )
ax[0].set_ylim( 0.80, 1.05)

ax[1].plot( iter_val, step1_rms )
ax[1].plot( iter_val, step2_rms )
ax[1].set_ylim( 0, 1.1*np.max(step1_rms))


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
n_boot_samples = 50
do_bootstrap = True

# %%
# %%time

rng = np.random.default_rng()

for bi in range(0,n_boot_samples) :
    
    if do_bootstrap :
        print("\n Creating bootstrap sample %3d" % bi )
        boot_true_det_pts = rng.choice( true_det_pts, size=len(true_det_pts) )
        
    else :
        print("\n Creating toy sample %3d" % bi )
        boot_true_pts = np.random.multivariate_normal(true_mu, true_cov, size=ngen_true)
        boot_true_det_pts = np.random.normal( boot_true_pts, [res0, res1])
        

        
#    boot_of_return_dict = of.omnifold6b( 
#        train_both, boot_true_det_pts, of_niter, model, verbose, 
#        batch_size_setval, learning_rate_setval, epochs_setval )

    rd = simple_pdf.simple_pdf1a( train_both, boot_true_det_pts, 
                             train_train_det_within_sphere, train_train_gen_within_sphere,
                             of_niter, radius, norm_radius2, False, False )

    mc_weight_sf = (1.*len(boot_true_det_pts))/(1.*len(train_both))



    boot_final_push_weights = rd["final_push_weights"]
    boot_final_push_weights_scaled = boot_final_push_weights
    boot_final_push_weights_scaled = mc_weight_sf * boot_final_push_weights
    
    print("\n\n bootstrap %d final push weights scaled:" % bi)
    print( boot_final_push_weights_scaled )

     
    with open( '%s/bootstrap-weights-%03d.npy' % ( output_dir, bi ), 'wb' ) as f :
        np.save( f, boot_final_push_weights_scaled )
        
    del boot_final_push_weights_scaled
    del rd
    gc.collect()
# Out:
#  Creating bootstrap sample   0
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.197746   0.39427743 0.89805181 ... 1.00525128 0.96498507 1.13401733]
#  weights_push at the beginning
# [1.26000128 0.29393172 0.81080865 ... 1.01747026 0.92940715 1.14874242]
#  weights_push at the beginning
# [1.28445628 0.26238674 0.77987275 ... 1.02809464 0.89706963 1.15699396]
#  weights_push at the beginning
# [1.29536329 0.24791894 0.77983666 ... 1.03635441 0.86899146 1.16920811]
#
#
#  bootstrap 0 final push weights scaled:
# [0.13000261 0.02391272 0.07958306 ... 0.10430166 0.08452336 0.11834378]
#
#  Creating bootstrap sample   1
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.16498273 0.47835971 1.06414569 ... 1.02139908 1.0217967  1.12677321]
#  weights_push at the beginning
# [1.21724206 0.39876851 1.0541807  ... 1.03952784 1.02356759 1.15337577]
#  weights_push at the beginning
# [1.23892443 0.38812293 1.05395578 ... 1.05153926 1.01702412 1.17415382]
#  weights_push at the beginning
# [1.24991492 0.3957661  1.05890747 ... 1.05923423 1.00795772 1.19700084]
#
#
#  bootstrap 1 final push weights scaled:
# [0.125609   0.04089129 0.10629769 ... 0.1064427  0.09990045 0.12200359]
#
#  Creating bootstrap sample   2
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.15934334 0.41816678 0.95899715 ... 0.9996856  0.95719345 1.14172817]
#  weights_push at the beginning
# [1.20072652 0.31749606 0.902101   ... 1.00563572 0.91552724 1.17194868]
#  weights_push at the beginning
# [1.21226766 0.28792675 0.88887251 ... 1.00960507 0.87761469 1.19439561]
#  weights_push at the beginning
# [1.21441119 0.27845428 0.90261016 ... 1.01133788 0.8444237  1.21894846]
#
#
#  bootstrap 2 final push weights scaled:
# [0.12128141 0.027717   0.09312526 ... 0.10117839 0.08159397 0.12440651]
#
#  Creating bootstrap sample   3
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.17727926 0.40495364 0.8862133  ... 1.01814467 1.00358472 1.10135068]
#  weights_push at the beginning
# [1.23006541 0.30301086 0.75624253 ... 1.03456337 0.99100227 1.10438648]
#  weights_push at the beginning
# [1.2494831  0.27079614 0.6702178  ... 1.04567732 0.97387932 1.10820912]
#  weights_push at the beginning
# [1.25756141 0.25632701 0.61102624 ... 1.05284538 0.95709743 1.1186417 ]
#
#
#  bootstrap 3 final push weights scaled:
# [0.12607476 0.02475786 0.05672275 ... 0.10577351 0.09425649 0.11321098]
#
#  Creating bootstrap sample   4
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.17185474 0.42474304 0.92033768 ... 1.02825894 0.99085372 1.13443435]
#  weights_push at the beginning
# [1.22451441 0.32420815 0.84552053 ... 1.05287996 0.96740821 1.16771908]
#  weights_push at the beginning
# [1.24440562 0.29092654 0.81537181 ... 1.07083262 0.94011173 1.19384622]
#  weights_push at the beginning
# [1.25286351 0.27411191 0.80920277 ... 1.08376011 0.91332875 1.22083217]
#
#
#  bootstrap 4 final push weights scaled:
# [0.12562898 0.02627108 0.08141273 ... 0.10934942 0.08886586 0.12469375]
#
#  Creating bootstrap sample   5
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.13640948 0.4393978  1.04322495 ... 1.01262298 0.97210737 1.12639959]
#  weights_push at the beginning
# [1.16020158 0.33796765 1.01907218 ... 1.02582102 0.94097549 1.1460102 ]
#  weights_push at the beginning
# [1.15764105 0.30523131 1.01313697 ... 1.0345053  0.91191848 1.16047416]
#  weights_push at the beginning
# [1.14784115 0.29061598 1.01881544 ... 1.03958603 0.88683906 1.17843028]
#
#
#  bootstrap 5 final push weights scaled:
# [0.11357636 0.02821789 0.10283518 ... 0.10425311 0.08660858 0.11978307]
#
#  Creating bootstrap sample   6
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.16014881 0.43211675 1.03976905 ... 1.02285029 0.9820891  1.13352947]
#  weights_push at the beginning
# [1.20117834 0.3409181  1.02242165 ... 1.04285991 0.9523424  1.16244642]
#  weights_push at the beginning
# [1.21169054 0.31730529 1.02928942 ... 1.05646719 0.92089886 1.18633741]
#  weights_push at the beginning
# [1.21259315 0.30945223 1.05445324 ... 1.06537497 0.89166828 1.21340552]
#
#
#  bootstrap 6 final push weights scaled:
# [0.12097738 0.03060016 0.10912515 ... 0.10715092 0.08660399 0.12413489]
#
#  Creating bootstrap sample   7
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.19557365 0.37712295 0.98533778 ... 1.01584654 1.01063302 1.21308523]
#  weights_push at the beginning
# [1.24254302 0.2728035  0.90479894 ... 1.0375751  1.0066632  1.26906751]
#  weights_push at the beginning
# [1.25093031 0.23773716 0.86410857 ... 1.05555303 0.99624397 1.30621083]
#  weights_push at the beginning
# [1.2473573  0.22044677 0.85066831 ... 1.06920606 0.98363888 1.34207925]
#
#
#  bootstrap 7 final push weights scaled:
# [0.1239407  0.02094949 0.08516317 ... 0.10797595 0.09711268 0.13765589]
#
#  Creating bootstrap sample   8
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.16157347 0.41120462 0.87151562 ... 1.0276031  1.01080783 1.10490701]
#  weights_push at the beginning
# [1.20485849 0.32426767 0.78177623 ... 1.04948998 0.99908174 1.12402188]
#  weights_push at the beginning
# [1.21716832 0.31097244 0.74571584 ... 1.06403267 0.9795989  1.14412402]
#  weights_push at the beginning
# [1.21932742 0.31825246 0.73673414 ... 1.07341516 0.95874435 1.16912189]
#
#
#  bootstrap 8 final push weights scaled:
# [0.12173319 0.03330852 0.07412453 ... 0.10797202 0.09391586 0.11954739]
#
#  Creating bootstrap sample   9
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.17410528 0.38472174 0.82074911 ... 1.02367385 0.98932449 1.17692992]
#  weights_push at the beginning
# [1.21609645 0.27754548 0.64806387 ... 1.04758134 0.96643942 1.22631498]
#  weights_push at the beginning
# [1.22375941 0.24310795 0.53420153 ... 1.06576826 0.94075721 1.26323736]
#  weights_push at the beginning
# [1.22080654 0.22911902 0.45356713 ... 1.07917279 0.91644412 1.30071155]
#
#
#  bootstrap 9 final push weights scaled:
# [0.12139811 0.0223339  0.03916017 ... 0.10895254 0.08950744 0.13381027]
#
#  Creating bootstrap sample  10
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.16704812 0.43060967 0.87978114 ... 1.01035984 0.97798618 1.14304472]
#  weights_push at the beginning
# [1.20536644 0.34824177 0.73935401 ... 1.0251895  0.95077058 1.1614103 ]
#  weights_push at the beginning
# [1.21223742 0.33559895 0.64825403 ... 1.03646213 0.92355026 1.17230216]
#  weights_push at the beginning
# [1.20993274 0.34052927 0.58664581 ... 1.04420179 0.89838635 1.18679003]
#
#
#  bootstrap 10 final push weights scaled:
# [0.12044182 0.03504625 0.05410002 ... 0.10497309 0.08761241 0.12029892]
#
#  Creating bootstrap sample  11
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.19752918 0.40761628 0.83922256 ... 1.02042471 1.02676218 1.09826891]
#  weights_push at the beginning
# [1.26468029 0.31489116 0.72695135 ... 1.03817132 1.02789626 1.10260453]
#  weights_push at the beginning
# [1.29422625 0.29092777 0.67465238 ... 1.05020615 1.01872797 1.107992  ]
#  weights_push at the beginning
# [1.309873   0.28371585 0.6519512  ... 1.05793302 1.00620899 1.11936303]
#
#
#  bootstrap 11 final push weights scaled:
# [0.13190158 0.02818744 0.06424456 ... 0.10630698 0.09935355 0.11331158]
#
#  Creating bootstrap sample  12
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.1909552  0.37691408 0.92873869 ... 1.02684955 1.02204593 1.10276701]
#  weights_push at the beginning
# [1.25193956 0.27698285 0.87435368 ... 1.0461432  1.01614452 1.11491822]
#  weights_push at the beginning
# [1.27603554 0.24913177 0.86765256 ... 1.05802904 1.00041694 1.12826725]
#  weights_push at the beginning
# [1.28690239 0.24043141 0.88475471 ... 1.06509518 0.98222197 1.14696875]
#
#
#  bootstrap 12 final push weights scaled:
# [0.12918561 0.02384854 0.09109457 ... 0.10695686 0.09647642 0.11672863]
#
#  Creating bootstrap sample  13
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.18268228 0.39233119 0.90277564 ... 1.01366645 0.97517715 1.12007718]
#  weights_push at the beginning
# [1.23857603 0.29155132 0.8123187  ... 1.029941   0.94318687 1.13685892]
#  weights_push at the beginning
# [1.2601062  0.26027815 0.77105015 ... 1.04304371 0.91137143 1.15133756]
#  weights_push at the beginning
# [1.26982254 0.24586968 0.75586698 ... 1.05316966 0.88225381 1.17070517]
#
#
#  bootstrap 13 final push weights scaled:
# [0.12743757 0.02363023 0.07520255 ... 0.1061415  0.08565384 0.11920355]
#
#  Creating bootstrap sample  14
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.17223756 0.43234626 0.95279852 ... 1.00133148 0.97923588 1.13298673]
#  weights_push at the beginning
# [1.2218626  0.32577321 0.88541004 ... 1.00565459 0.95158751 1.15543778]
#  weights_push at the beginning
# [1.23853321 0.28692248 0.85724646 ... 1.00725021 0.92416191 1.17135641]
#  weights_push at the beginning
# [1.24397803 0.26572425 0.85099773 ... 1.00648654 0.89945584 1.19016403]
#
#
#  bootstrap 14 final push weights scaled:
# [0.12445577 0.02507385 0.08534817 ... 0.1004523  0.08782679 0.1209933 ]
#
#  Creating bootstrap sample  15
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.21057052 0.37059837 0.92459208 ... 1.00307776 0.99439286 1.16568233]
#  weights_push at the beginning
# [1.27569209 0.27222669 0.81424771 ... 1.01023001 0.97359959 1.19519573]
#  weights_push at the beginning
# [1.30087483 0.24393313 0.75004755 ... 1.01429996 0.9485588  1.21511752]
#  weights_push at the beginning
# [1.31231669 0.23414298 0.71269975 ... 1.01522841 0.92356147 1.23775693]
#
#
#  bootstrap 15 final push weights scaled:
# [0.13178381 0.02313158 0.06885219 ... 0.10142501 0.09004538 0.12612007]
#
#  Creating bootstrap sample  16
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.19798013 0.42124778 1.06227176 ... 1.01993264 1.00000297 1.13880396]
#  weights_push at the beginning
# [1.26106695 0.32455671 1.06267525 ... 1.04108077 0.98580392 1.15185597]
#  weights_push at the beginning
# [1.28669108 0.29568367 1.09375511 ... 1.05749261 0.96714178 1.15603778]
#  weights_push at the beginning
# [1.29911496 0.28391093 1.14578726 ... 1.06980271 0.94835384 1.16296252]
#
#
#  bootstrap 16 final push weights scaled:
# [0.13056047 0.02777542 0.12080468 ... 0.1079517  0.09312532 0.11711977]
#
#  Creating bootstrap sample  17
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.18771461 0.42902606 0.86841222 ... 1.00920859 0.99848892 1.18084899]
#  weights_push at the beginning
# [1.23698029 0.33205383 0.73321692 ... 1.01985871 0.98016327 1.22893825]
#  weights_push at the beginning
# [1.24886746 0.30216029 0.65147177 ... 1.02631486 0.95676845 1.26473684]
#  weights_push at the beginning
# [1.24839702 0.28961163 0.60006354 ... 1.02906148 0.9331383  1.3013183 ]
#
#
#  bootstrap 17 final push weights scaled:
# [0.12430066 0.02833227 0.05641956 ... 0.10294925 0.0911269  0.13374083]
#
#  Creating bootstrap sample  18
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.15622298 0.38332231 0.97494232 ... 1.04289812 0.99975677 1.10646567]
#  weights_push at the beginning
# [1.19387445 0.29244707 0.92796848 ... 1.07853227 0.97843866 1.11724197]
#  weights_push at the beginning
# [1.20332443 0.27514039 0.91664353 ... 1.10464809 0.94963861 1.12875947]
#  weights_push at the beginning
# [1.20476223 0.27747784 0.92372062 ... 1.12384467 0.91972004 1.14599291]
#
#
#  bootstrap 18 final push weights scaled:
# [0.12034583 0.02862595 0.09382438 ... 0.11387224 0.08914192 0.116549  ]
#
#  Creating bootstrap sample  19
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.17110284 0.38965464 0.95209729 ... 1.02268135 1.00357121 1.14355047]
#  weights_push at the beginning
# [1.21568485 0.27874671 0.88372629 ... 1.04538294 0.99208664 1.17411724]
#  weights_push at the beginning
# [1.22672037 0.23991551 0.85207363 ... 1.06304719 0.97549342 1.19748764]
#  weights_push at the beginning
# [1.22673067 0.22087427 0.83892852 ... 1.07643932 0.95825019 1.22331116]
#
#
#  bootstrap 19 final push weights scaled:
# [0.12223074 0.02092609 0.08324699 ... 0.10870426 0.09423135 0.12497403]
#
#  Creating bootstrap sample  20
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.16569451 0.40705154 1.0985799  ... 1.00374128 0.97957825 1.18372962]
#  weights_push at the beginning
# [1.20802842 0.30827001 1.09159777 ... 1.01178376 0.95440331 1.23157334]
#  weights_push at the beginning
# [1.22001557 0.27908724 1.09587943 ... 1.01637626 0.92895504 1.26410292]
#  weights_push at the beginning
# [1.22272878 0.26800621 1.11027807 ... 1.01770459 0.90535865 1.29552761]
#
#
#  bootstrap 20 final push weights scaled:
# [0.12218144 0.0263228  0.11275635 ... 0.10170568 0.08843839 0.13255302]
#
#  Creating bootstrap sample  21
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.17672716 0.36190904 0.90667584 ... 1.03788668 1.04002025 1.08892394]
#  weights_push at the beginning
# [1.23072079 0.26385323 0.83741222 ... 1.06752435 1.05002216 1.09444206]
#  weights_push at the beginning
# [1.25154418 0.23874574 0.8174825  ... 1.08894366 1.0472021  1.10369907]
#  weights_push at the beginning
# [1.261018   0.2317379  0.82285879 ... 1.10479035 1.0394911  1.11926334]
#
#
#  bootstrap 21 final push weights scaled:
# [0.12656274 0.02299536 0.08399135 ... 0.11173317 0.10305394 0.11369996]
#
#  Creating bootstrap sample  22
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.18091787 0.45042239 0.9361608  ... 1.00379406 0.95488987 1.13946856]
#  weights_push at the beginning
# [1.23145548 0.35750338 0.86860637 ... 1.01185845 0.90706682 1.16792165]
#  weights_push at the beginning
# [1.24711779 0.32765368 0.84973757 ... 1.01739493 0.86275859 1.19253936]
#  weights_push at the beginning
# [1.25125741 0.31209293 0.85748154 ... 1.02029821 0.82348202 1.22178324]
#
#
#  bootstrap 22 final push weights scaled:
# [0.12507424 0.03007702 0.08767126 ... 0.10216021 0.07893024 0.12529073]
#
#  Creating bootstrap sample  23
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.14768639 0.39136376 0.92115126 ... 1.04214552 1.00797684 1.1084324 ]
#  weights_push at the beginning
# [1.17836037 0.2965173  0.82731676 ... 1.07486091 0.98952087 1.12667055]
#  weights_push at the beginning
# [1.18070076 0.2729044  0.77447725 ... 1.09800637 0.96153854 1.14596977]
#  weights_push at the beginning
# [1.17492077 0.26715121 0.74668933 ... 1.11458738 0.93128845 1.17029341]
#
#
#  bootstrap 23 final push weights scaled:
# [0.11665092 0.02667886 0.07325265 ... 0.11272103 0.09020838 0.11957802]
#
#  Creating bootstrap sample  24
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.17231434 0.37927417 0.94365648 ... 1.00108199 0.97655086 1.19239817]
#  weights_push at the beginning
# [1.21221774 0.26782404 0.82465189 ... 1.00943121 0.94778932 1.23999083]
#  weights_push at the beginning
# [1.21920751 0.22639152 0.74032839 ... 1.01516626 0.9184809  1.27163131]
#  weights_push at the beginning
# [1.21634865 0.20397232 0.67792301 ... 1.01781163 0.89089647 1.30336995]
#
#
#  bootstrap 24 final push weights scaled:
# [0.12099356 0.01894405 0.06270953 ... 0.10185244 0.08661925 0.13350949]
#
#  Creating bootstrap sample  25
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.19531613 0.39927371 0.9604527  ... 1.00115196 0.97792495 1.16333916]
#  weights_push at the beginning
# [1.25715285 0.29680434 0.88777843 ... 1.0084965  0.94792396 1.19857556]
#  weights_push at the beginning
# [1.28196263 0.26492208 0.85544054 ... 1.01351134 0.91694891 1.22253564]
#  weights_push at the beginning
# [1.29376767 0.25160511 0.84620515 ... 1.01585107 0.88797665 1.24800421]
#
#
#  bootstrap 25 final push weights scaled:
# [0.12997422 0.02447073 0.08471198 ... 0.10164991 0.08620883 0.12739643]
#
#  Creating bootstrap sample  26
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.16816686 0.37656302 0.83288603 ... 1.02005834 0.98108151 1.09195057]
#  weights_push at the beginning
# [1.21373928 0.26050336 0.72845658 ... 1.0376935  0.94943139 1.09109045]
#  weights_push at the beginning
# [1.22708591 0.21717332 0.68902952 ... 1.04940512 0.91617141 1.09127693]
#  weights_push at the beginning
# [1.22986738 0.19410483 0.68251094 ... 1.05660549 0.88540527 1.0973786 ]
#
#
#  bootstrap 26 final push weights scaled:
# [0.12283409 0.01789819 0.06925245 ... 0.10610767 0.0858442  0.11059816]
#
#  Creating bootstrap sample  27
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.16151583 0.36766924 1.03080549 ... 1.01056791 0.97393433 1.15831403]
#  weights_push at the beginning
# [1.19678957 0.25322511 0.99865873 ... 1.02539626 0.94216279 1.19004356]
#  weights_push at the beginning
# [1.20096818 0.21127962 0.99583696 ... 1.0367964  0.90987849 1.21167307]
#  weights_push at the beginning
# [1.19596181 0.18915078 1.01265905 ... 1.04480052 0.87926213 1.23515944]
#
#
#  bootstrap 27 final push weights scaled:
# [0.11877269 0.01745727 0.10385352 ... 0.10506301 0.08514175 0.12591216]
#
#  Creating bootstrap sample  28
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.190689   0.4123079  0.93170051 ... 1.00135756 0.97080335 1.11794276]
#  weights_push at the beginning
# [1.24518643 0.33151883 0.86350196 ... 1.00890461 0.93748622 1.12556788]
#  weights_push at the beginning
# [1.26339509 0.32190402 0.84304502 ... 1.0149582  0.9060143  1.13189749]
#  weights_push at the beginning
# [1.26949559 0.33179975 0.8471841  ... 1.01885165 0.87803475 1.1444725 ]
#
#
#  bootstrap 28 final push weights scaled:
# [0.12705205 0.03489811 0.08618957 ... 0.10213903 0.08538763 0.11601098]
#
#  Creating bootstrap sample  29
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.16319968 0.42119175 0.91653334 ... 1.01556383 0.98221126 1.13316598]
#  weights_push at the beginning
# [1.2023847  0.31951791 0.81937477 ... 1.03132249 0.95402316 1.16054653]
#  weights_push at the beginning
# [1.20981422 0.28702571 0.76465148 ... 1.04261878 0.92503655 1.18478126]
#  weights_push at the beginning
# [1.20740233 0.27267883 0.73302124 ... 1.05041402 0.89877091 1.21356988]
#
#
#  bootstrap 29 final push weights scaled:
# [0.12013528 0.02646094 0.0711974  ... 0.10562007 0.08762671 0.12442278]
#
#  Creating bootstrap sample  30
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.17310508 0.4016603  0.92505227 ... 1.00449994 0.96492243 1.13328863]
#  weights_push at the beginning
# [1.21930529 0.30919446 0.83488539 ... 1.0127159  0.92861399 1.15475114]
#  weights_push at the beginning
# [1.23320267 0.28742417 0.78950909 ... 1.01840844 0.89549704 1.17248552]
#  weights_push at the beginning
# [1.23678498 0.28373682 0.77160084 ... 1.0215901  0.86648573 1.1946796 ]
#
#
#  bootstrap 30 final push weights scaled:
# [0.12362019 0.02857776 0.07690671 ... 0.10233214 0.0841646  0.12184014]
#
#  Creating bootstrap sample  31
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.20653628 0.38951617 1.0864388  ... 1.01839962 1.00321775 1.14116745]
#  weights_push at the beginning
# [1.27284667 0.28976296 1.09362462 ... 1.0359815  0.98524731 1.15832374]
#  weights_push at the beginning
# [1.30060945 0.25835557 1.12255828 ... 1.0480233  0.95989634 1.17131064]
#  weights_push at the beginning
# [1.3150751  0.24366024 1.1645174  ... 1.05572394 0.93323221 1.18987438]
#
#
#  bootstrap 31 final push weights scaled:
# [0.13237672 0.02342419 0.12092564 ... 0.10609322 0.090829   0.12112542]
#
#  Creating bootstrap sample  32
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.20111711 0.38463671 0.97098325 ... 1.00442144 0.97416657 1.14952116]
#  weights_push at the beginning
# [1.26488188 0.28038108 0.89265271 ... 1.01607036 0.9455684  1.16808159]
#  weights_push at the beginning
# [1.29156282 0.24608484 0.85079782 ... 1.02558033 0.91792095 1.17881683]
#  weights_push at the beginning
# [1.30549134 0.23029094 0.83001099 ... 1.03219688 0.89286928 1.19380396]
#
#
#  bootstrap 32 final push weights scaled:
# [0.13137663 0.02213909 0.08184908 ... 0.10368104 0.08710197 0.12112726]
#
#  Creating bootstrap sample  33
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.18567449 0.3568195  0.84517218 ... 0.999202   0.9838999  1.10381094]
#  weights_push at the beginning
# [1.2418219  0.25300018 0.73956293 ... 1.0036092  0.96229169 1.10477104]
#  weights_push at the beginning
# [1.26305934 0.22063929 0.69813085 ... 1.00610219 0.94109022 1.10458633]
#  weights_push at the beginning
# [1.27230753 0.20649418 0.69091422 ... 1.00633478 0.92227706 1.10996925]
#
#
#  bootstrap 33 final push weights scaled:
# [0.12762879 0.01993025 0.07018782 ... 0.10051902 0.09064236 0.1117859 ]
#
#  Creating bootstrap sample  34
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.17415538 0.44320206 0.96733284 ... 1.01581851 0.97794508 1.14738659]
#  weights_push at the beginning
# [1.21771278 0.35761248 0.90515885 ... 1.03587278 0.94985932 1.17058266]
#  weights_push at the beginning
# [1.22816898 0.3388654  0.88315109 ... 1.0523135  0.92102531 1.18534464]
#  weights_push at the beginning
# [1.22846769 0.33610152 0.88300583 ... 1.06503303 0.89376614 1.20293   ]
#
#
#  bootstrap 34 final push weights scaled:
# [0.12250151 0.03374396 0.08914082 ... 0.10752567 0.08690537 0.12217104]
#
#  Creating bootstrap sample  35
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.1774947  0.39988352 0.86439228 ... 1.00871282 0.97304899 1.13721536]
#  weights_push at the beginning
# [1.22825134 0.29909847 0.71914738 ... 1.02048228 0.93714173 1.15868921]
#  weights_push at the beginning
# [1.24568469 0.26957188 0.62351416 ... 1.02875574 0.9004145  1.17468621]
#  weights_push at the beginning
# [1.25214052 0.25929106 0.55700387 ... 1.0340124  0.86604203 1.19507262]
#
#
#  bootstrap 35 final push weights scaled:
# [0.12540201 0.02560598 0.05068533 ... 0.10376357 0.08353801 0.12176977]
#
#  Creating bootstrap sample  36
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.20556893 0.34193326 0.93941621 ... 1.02107462 0.97946498 1.18703003]
#  weights_push at the beginning
# [1.27211484 0.22703907 0.82364246 ... 1.04529739 0.94860422 1.23085626]
#  weights_push at the beginning
# [1.30093852 0.18365272 0.7491473  ... 1.06443674 0.91533817 1.25939188]
#  weights_push at the beginning
# [1.31694105 0.15881586 0.70356794 ... 1.07875525 0.88345452 1.28785916]
#
#
#  bootstrap 36 final push weights scaled:
# [0.1327389  0.01413634 0.06746117 ... 0.10898326 0.08545255 0.1315609 ]
#
#  Creating bootstrap sample  37
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.18712589 0.44227349 0.96154749 ... 1.00845924 0.98189297 1.14458548]
#  weights_push at the beginning
# [1.24397838 0.34954526 0.9041487  ... 1.0200641  0.95410641 1.17211101]
#  weights_push at the beginning
# [1.26415467 0.32412577 0.88926811 ... 1.02870175 0.92491261 1.1908547 ]
#  weights_push at the beginning
# [1.27105297 0.31546242 0.89862044 ... 1.03461009 0.89759458 1.21136826]
#
#
#  bootstrap 37 final push weights scaled:
# [0.12718008 0.03119896 0.09191913 ... 0.10389319 0.08732974 0.12322107]
#
#  Creating bootstrap sample  38
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.18551662 0.35111982 0.77994534 ... 0.99997329 0.97741163 1.11091907]
#  weights_push at the beginning
# [1.24109926 0.24787683 0.61919799 ... 1.00177628 0.94541675 1.11948966]
#  weights_push at the beginning
# [1.26167813 0.21535899 0.52656422 ... 1.00081229 0.91257462 1.12748406]
#  weights_push at the beginning
# [1.2703751  0.1995295  0.46846121 ... 0.99764205 0.88172472 1.14126824]
#
#
#  bootstrap 38 final push weights scaled:
# [0.12739685 0.01897512 0.04278318 ... 0.09934984 0.08547868 0.11574656]
#
#  Creating bootstrap sample  39
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.19749975 0.44865584 0.94338177 ... 1.01447103 0.99535791 1.13691729]
#  weights_push at the beginning
# [1.25697463 0.36635144 0.88077086 ... 1.02996059 0.97424464 1.15423994]
#  weights_push at the beginning
# [1.2773102  0.35093131 0.86372486 ... 1.04098347 0.94887016 1.16451899]
#  weights_push at the beginning
# [1.28377471 0.35159463 0.86910371 ... 1.04815434 0.92413675 1.1782933 ]
#
#
#  bootstrap 39 final push weights scaled:
# [0.12841278 0.03568078 0.08831341 ... 0.10529099 0.09019346 0.11937494]
#
#  Creating bootstrap sample  40
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.17902932 0.37137308 0.88037958 ... 1.00154969 0.97051515 1.08444019]
#  weights_push at the beginning
# [1.23242316 0.25903777 0.77288191 ... 1.00647446 0.93464548 1.07806263]
#  weights_push at the beginning
# [1.25142711 0.2182838  0.71258745 ... 1.00933423 0.9003848  1.07494734]
#  weights_push at the beginning
# [1.25834339 0.19638697 0.67680186 ... 1.01029668 0.87008326 1.07954852]
#
#
#  bootstrap 40 final push weights scaled:
# [0.12597811 0.01814189 0.06532191 ... 0.10103415 0.08441845 0.10880929]
#
#  Creating bootstrap sample  41
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.1999252  0.38052566 0.96904382 ... 1.00296634 0.96993781 1.11424025]
#  weights_push at the beginning
# [1.26572226 0.26997121 0.92534024 ... 1.01024014 0.9335407  1.118061  ]
#  weights_push at the beginning
# [1.29319131 0.2301377  0.92602235 ... 1.01533567 0.89864911 1.11981972]
#  weights_push at the beginning
# [1.30645927 0.20925718 0.95053662 ... 1.01810938 0.86757517 1.12763332]
#
#
#  bootstrap 41 final push weights scaled:
# [0.13129497 0.01955934 0.09847313 ... 0.10195013 0.08407971 0.1138672 ]
#
#  Creating bootstrap sample  42
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.20127784 0.3547838  0.96069715 ... 0.98643987 0.96391762 1.15256983]
#  weights_push at the beginning
# [1.25904757 0.25205953 0.87355671 ... 0.9845806  0.92611094 1.16703266]
#  weights_push at the beginning
# [1.27761017 0.22370403 0.82771293 ... 0.98348006 0.89076926 1.17254233]
#  weights_push at the beginning
# [1.28265326 0.2170225  0.80686717 ... 0.98173098 0.85911314 1.18233525]
#
#
#  bootstrap 42 final push weights scaled:
# [0.12817228 0.02196088 0.07978358 ... 0.09798484 0.08320299 0.11947037]
#
#  Creating bootstrap sample  43
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.17522331 0.40704337 0.98909733 ... 0.98877151 0.94458941 1.17594396]
#  weights_push at the beginning
# [1.21725542 0.30532724 0.90129477 ... 0.99056088 0.89764307 1.20368432]
#  weights_push at the beginning
# [1.22665358 0.26981468 0.8468253  ... 0.99256963 0.85760067 1.2162854 ]
#  weights_push at the beginning
# [1.22649186 0.25059716 0.81595776 ... 0.99317138 0.82357704 1.23006225]
#
#
#  bootstrap 43 final push weights scaled:
# [0.12229296 0.02377294 0.07973559 ... 0.09929309 0.07950557 0.12447393]
#
#  Creating bootstrap sample  44
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.19665518 0.38357429 0.81211314 ... 1.02115148 0.99381264 1.11720068]
#  weights_push at the beginning
# [1.25577129 0.28374128 0.66450077 ... 1.04253777 0.97090951 1.12016289]
#  weights_push at the beginning
# [1.27694317 0.25337269 0.58237627 ... 1.05865031 0.94325389 1.11929812]
#  weights_push at the beginning
# [1.28505479 0.24128497 0.53424244 ... 1.07023694 0.9156319  1.1232766 ]
#
#
#  bootstrap 44 final push weights scaled:
# [0.12875486 0.02358821 0.05034271 ... 0.10789336 0.08900396 0.11294737]
#
#  Creating bootstrap sample  45
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.22904614 0.48361963 1.00002036 ... 1.00104825 1.00471372 1.17545076]
#  weights_push at the beginning
# [1.30506409 0.421123   0.90753526 ... 1.0111109  0.99861622 1.19365219]
#  weights_push at the beginning
# [1.33786008 0.42108854 0.84638552 ... 1.01972894 0.98883089 1.19881226]
#  weights_push at the beginning
# [1.35528594 0.43388641 0.80701097 ... 1.0258153  0.97869297 1.20752573]
#
#
#  bootstrap 45 final push weights scaled:
# [0.13658046 0.04486877 0.07776093 ... 0.10302061 0.09697942 0.12188012]
#
#  Creating bootstrap sample  46
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.20316707 0.42005377 0.91406694 ... 1.02489552 1.01342483 1.17762011]
#  weights_push at the beginning
# [1.26678863 0.32433812 0.80396203 ... 1.0513478  1.00792398 1.21858751]
#  weights_push at the beginning
# [1.29159591 0.29809221 0.74501346 ... 1.07243021 0.99492606 1.24541833]
#  weights_push at the beginning
# [1.30302691 0.29036291 0.71791029 ... 1.08865316 0.98002753 1.27237256]
#
#
#  bootstrap 46 final push weights scaled:
# [0.13087274 0.02892655 0.07078365 ... 0.11015749 0.09658186 0.12988532]
#
#  Creating bootstrap sample  47
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.19351266 0.38071432 0.85424964 ... 1.00302246 0.98301313 1.12431545]
#  weights_push at the beginning
# [1.25394524 0.26928941 0.71511364 ... 1.0060674  0.94940131 1.14482104]
#  weights_push at the beginning
# [1.2767126  0.22911134 0.62883599 ... 1.00520344 0.91306798 1.1651898 ]
#  weights_push at the beginning
# [1.28602594 0.20821502 0.57183033 ... 1.00147488 0.87900536 1.1920615 ]
#
#
#  bootstrap 47 final push weights scaled:
# [0.12893373 0.01947228 0.05297034 ... 0.09963525 0.08488264 0.12218199]
#
#  Creating bootstrap sample  48
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.21314587 0.3951993  0.87011736 ... 0.98892406 0.96468303 1.12892827]
#  weights_push at the beginning
# [1.2851456  0.27948716 0.77297004 ... 0.9894456  0.92904722 1.13528753]
#  weights_push at the beginning
# [1.31586478 0.23328667 0.7397177  ... 0.99118413 0.89693284 1.13600275]
#  weights_push at the beginning
# [1.33114712 0.20616459 0.74071548 ... 0.99241883 0.86920104 1.14193443]
#
#
#  bootstrap 48 final push weights scaled:
# [0.13391013 0.01867346 0.07583526 ... 0.09933662 0.08458054 0.1150911 ]
#
#  Creating bootstrap sample  49
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.17194551 0.37908992 0.88993099 ... 1.03272588 0.98293981 1.11340582]
#  weights_push at the beginning
# [1.21582279 0.28122719 0.79701181 ... 1.06105516 0.95108807 1.12763323]
#  weights_push at the beginning
# [1.22671474 0.25402189 0.75628443 ... 1.08219637 0.91632122 1.14211802]
#  weights_push at the beginning
# [1.22727238 0.24502389 0.74259565 ... 1.09785667 0.8830331  1.16247125]
#
#
#  bootstrap 49 final push weights scaled:
# [0.12239575 0.02424872 0.07421971 ... 0.11100617 0.0852782  0.11851687]
# CPU times: user 1h 43min 7s, sys: 204 ms, total: 1h 43min 7s
# Wall time: 1h 43min 8s
